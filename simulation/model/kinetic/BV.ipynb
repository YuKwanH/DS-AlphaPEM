# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
import re
from PIL.ImageColor import colormap
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from scipy.integrate import solve_ivp
from scipy.optimize import curve_fit
from pathlib import Path

# %%
# --------------- Set up project root path  --------------- #
project_folder_name = "MFC2024" # Set this to the name of your project root folderS
project_root = next((p for p in [Path.cwd(), *Path.cwd().parents] if p.name == project_folder_name), None)
if project_root is None:
    raise FileNotFoundError(f"Could not locate project root folder named '{project_folder_name}'.")
print("Project root path:")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from config.settings import *
from model.coefficients import *
from config.initialize import *
# Out:
# Project root path:

# %%
C_O2_ccl =  np.linspace(4,9,10)
Tccl = np.linspace(323.15,343.15,10)

# %%
iload = np.linspace(0.1, 1.5, 10) * 1e4
eta_c = R * Tccl / (2*F) * np.log(iload/parameters["i0_c_ref"] * (C_O2_ccl/4.2)**(-parameters["kappa_c"]))

# %%
plt.plot(iload, eta_c)
