# %% [markdown]
# # Catalyst parameter calibration template
#
# ## Abstract
#
# This manuscript intend to illustrate the procedure of calibrating the chemical dissolution parameters. The execution time of this example will be around 80 minutes, which
#
# can be saved by reducing the number of trials of the optimizer

# %%
# Importing the necessary libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.integrate import solve_ivp, trapezoid
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## defining the kinetic equations
#
# ### Global parameters
# These parameters are constant that won't change anywhere

# %%
F = 96485  # C. mol-1. It is the Faraday constant.
R = 8.314  # J. mol-1.K-1. It is the universal gas constant.
rho_H2O = 997  # (kg/m3)
M_H2O = 18.02e-3  # kg/mol
alpha_4 = 0.5
rho_cc = 2.26 
Mcc = 12.01 
Ueq_4 = 0.2
Vm_Pt = 9.09  # Molar volume of Pt cm3/mol
M_Pt = 195.0849  # Molar mass of platinum (g/mol)
Cpt2_ref = 1e-3
rho_Pt = 21.45  # Density of platinum g/cm^3
GAMMA_max = 2.18e-9 # GAMMA(strong assumption): The active site quantity in moles per platinum area (mole/cm^2)

def Cproton_CCL(lambda_w, EW=1.1, rho_mem=0.002):
    return 1 / ((EW / rho_mem) + lambda_w * (M_H2O / rho_H2O))

# %% [markdown]
# ### Kinetic equations
#
# R1: PtDissolution()
#
# R2: PtOxidation()
#
# R3: PtOxideDissolution()
#
# R4: PtDetachment()

# %%
def PtDissolution(Ucell, Tccl,  theta, Cpt2, k1, k1_ref, **kwarg):

    alpha_1 = 0.5
    Ueq_1 = 1.15  # Standard equilibrium potential Ueq_1
    n = 2  # Electron transferred
    # Modelled as Butler-Volmer equation
    Rf = np.exp((alpha_1 * F * n) / (R * Tccl) * (Ucell - Ueq_1))  # Forward
    Rb = Cpt2 / Cpt2_ref * np.exp((-(1 - alpha_1) * F * n) / (R * Tccl) * (Ucell - Ueq_1))  # Reverse
    return k1 * (1 - theta) * Rf - k1_ref * Rb

def PtOxidation(Ucell, Tccl, Ch, theta, k2, k2_ref, **kwarg):

    # Standard equilibrium potential Ueq_2
    Ueq_2 = 0.97
    n = 2
    alpha_2 = 0.5
    omega = 27e3
    Ch_ref = 1e-3

    Rf = (k2 * np.exp(-omega * theta / (R * Tccl)) *
          np.exp((alpha_2 * F * n) / (R * Tccl) * (Ucell - Ueq_2)))
    Rb = (k2_ref * theta * (Ch / Ch_ref) ** 2 *
          np.exp((-alpha_2 * F * n) / (R * Tccl) * (Ucell - Ueq_2)))

    return Rf - Rb

def PtOxideDissolution(theta, Ch, k3, **kwarg):

    return k3 * theta * Ch ** 2

def PtDetachment(Ucell, Tccl, r, k4_ref, **kwarg):

    n = 2
    return k4_ref * Mcc / rho_cc * np.exp((alpha_4 * F * n) / (R * Tccl) * (Ucell - Ueq_4)) / r

# %% [markdown]
# ## Setup the simulation
#
# ### Eletrocde material parameters
#
# These parameters are related to the particle groups initialization

# %%
n_group_ptParticle = 50
rmin = 1e-8
rmax = 1e-6
dr = 1e-6 / n_group_ptParticle
r_m = (np.linspace(rmin, rmax, n_group_ptParticle + 1) + dr / 2)[1:]

# %%
def initPRD(resolution=100, rmin=1e-8, rmax=1e-6, std=0.549, mu=0.538):
    
    radius = np.linspace(rmin, rmax, resolution)
    pdf = 1/(std*np.sqrt(4*np.pi)) * np.exp(-(np.log(radius*1e7)-mu)**2/(std**2*2))
    return pdf

# %%
plt.figure(figsize=(6,2.5))
plt.scatter(r_m,initPRD(50))
plt.xlabel("Radius of the group(cm)")
plt.ylabel("Density")
# Out:
# Text(0, 0.5, 'Density')

# %% [markdown]
# ## AST protocol

# %%
def ucell_sw(t):
    
    t = t%6
    t_stop = 6
    iload_rise =  0.2 * np.tanh(8*(t - t_stop / 4)) + 0.3
    iload_drop =  -0.2 * np.tanh(8*(t - t_stop * 3 / 4)) +0.3
    return iload_rise  + iload_drop

# def ucell_tw(t):
    
#     t = t%6
#     UPL = 0.95
#     LPL = 0.60
#     v_scan = 0.125
#     u = (UPL-LPL)/np.pi*np.arcsin(np.sin((np.pi*v_scan)/(UPL-LPL)*t-np.pi/2))+(UPL-LPL)/2+LPL
#     return u

# %%
fig, ax = plt.subplots(figsize=(6,2.5))
ax.plot(ucell_sw(np.arange(0,30,0.1)))
ax.set_xlabel("Time (ms)")
ax.set_ylabel("Ucell")
# Out:
# Text(0, 0.5, 'Ucell')

# %% [markdown]
# ## Defining the CCL class that represent the Pt loading

# %%
class ccl():
    
    def __init__(self):
        
        self.Ucell = ucell_sw
        self.Tfc = 353.15
        self.parameters = {"krdp": 1e-10, "k1":3e-9, "k1_ref":1e-18, "k2": 1e-13, "k2_ref": 1e-13, "k3": 1e-15, "k4": 0, "k5":0, "k4_ref":1.7e-21}
        self.prd0 = initPRD(resolution=n_group_ptParticle)
        
    def dxdt(self, t, x):
            
        C_Pt2_ccl = x[0]
        theta_CCL = x[1:1+len(r_m)]
        prd = x[-len(r_m):]
        u = self.Ucell(t)
        
        # CCL kinetic
        # 0.043 + 17.81*0.85 - 39.85*0.85**2 + 36*0.85**3 = 8.5
        R0 = (2*9.09*0.2e-4)/(R*353)
        C_H_CCL = Cproton_CCL(lambda_w=8.5)
        kdis = PtDissolution(u, self.Tfc, C_Pt2_ccl, theta_CCL, **self.parameters)
        kox = PtOxidation(u, self.Tfc, C_H_CCL, theta_CCL, **self.parameters)
        kcdis = PtOxideDissolution(theta_CCL, C_H_CCL, **self.parameters)
        kdet = PtDetachment(u, self.Tfc, r_m, **self.parameters)
        drdt = Vm_Pt * self.parameters["krdp"] * C_Pt2_ccl * np.exp(-R0 / r_m) - Vm_Pt * (kdis + kox) * Cpt2_ref * np.exp(R0 / r_m)
        M_Pt0 = 4 / 3 * np.pi * rho_Pt * trapezoid(y=self.prd0 * r_m ** 3, x=r_m)
        dMdisdt = 4 * np.pi * rho_Pt * trapezoid(y=prd * r_m ** 2 * drdt, x=r_m)
        dMcdisdt = 4 * np.pi * rho_Pt * trapezoid(y=prd * r_m ** 2 * kcdis, x=r_m)
        dC_Pt2_ccl = -3.33 / M_Pt * (dMdisdt - dMcdisdt) / M_Pt0
        dfdt = -np.gradient(prd * drdt, r_m) - kdet * prd
        dthetadt = (((kox - kcdis) / GAMMA_max) - (2 * theta_CCL / r_m) * drdt)
        
        dxdt = [0]*(1+len(r_m)*2)
        dxdt[0] = dC_Pt2_ccl
        dxdt[1:1+len(r_m)] = dthetadt
        dxdt[-len(r_m):] = dfdt
        
        return dxdt

# %% [markdown]
# An example of the Pt particle degradation evolution

# %%
model = ccl()
model.Ucell = ucell_sw
x_init = [0] + [0]*len(r_m) + model.prd0.tolist()
sol = solve_ivp(fun=model.dxdt, y0 = x_init, t_span=(0, 12),max_step=1e-1, method='BDF')
fig, ax = plt.subplots(nrows=1,ncols=3,figsize=(18,3))
ax[0].plot(sol.t, sol.y[0,:])
ax_twin = ax[0].twinx()
ax_twin.plot(sol.t, [ucell_sw(t) for t in sol.t], color = '#0AD0EF', linestyle = '--')
ax[1].plot(sol.t, sol.y[35,:])
ax_twin = ax[1].twinx()
ax_twin.plot(sol.t, [ucell_sw(t) for t in sol.t], color = '#0AD0EF', linestyle = '--')
ax[2].plot(sol.t, sol.y[-15,:])
ax_twin = ax[2].twinx()
ax_twin.plot(sol.t, [ucell_sw(t) for t in sol.t], color = '#0AD0EF', linestyle = '--')

# %% [markdown]
# ## Case study: Automatic calibration
#
# The automatic calibration applies the experiment data from H. A. Baroody and E. Kjeang, J. Electrochem. Soc., vol. 168, no. 4, p. 044524, Apr. 2021. The search region can be
#
# narrow down according to prior knowledge about the Pt loading on the well-knowed stack.
#
# It's suggested that to select a parallel execution for the optimizer to reduce the computation time.
#
# The cell below can be copied to an individual Python file for execution

# %%
import optuna

def objective(trial):
        # Defining the search region
        krdp_trial = trial.suggest_float("krdp",1e-13,  1e-7, log=True)
        k1_trial = trial.suggest_float("k1", 1e-17, 1e-11, log=True)
        k2_trial = trial.suggest_float("k2", 1e-17, 1e-11, log=True)
        k3_trial = trial.suggest_float("k3", 1e-17, 1e-13, log=True)
        k4_ref_trial = trial.suggest_float("k4_ref", 1e-24, 1e-18, log=True)

        # Per-trial model: optuna with n_jobs > 1 runs trials in parallel
        # threads, so the model object must NOT be shared across trials --
        # otherwise mutating model.parameters causes data races.
        model = ccl()
        model.parameters["krdp"] = krdp_trial
        model.parameters["k1"] = k1_trial
        model.parameters["k2"] = k2_trial
        model.parameters["k3"] = k3_trial
        model.parameters["k4_ref"] = k4_ref_trial

        # Initial state for cycle 0
        x = [0] + [0]*len(r_m) + model.prd0.tolist()

        sol_hist = []
        for i_cycle in range(7):
                sol = solve_ivp(fun=model.dxdt, y0=x, t_span=(0, 5000*6), method="BDF")
                sol_hist.append(sol)
                # Carry the final state of this cycle into the next one;
                # otherwise every cycle starts fresh and sim_data is just
                # seven copies of the cycle-0 ECSA.
                x = sol.y[:, -1]

        sim_data = [1] + [
                (trapezoid(y=(r_m ** 2) * sol_hist[i_sol+1].y[-len(r_m):, -1], x=r_m))
                / (trapezoid(y=(r_m ** 2) * model.prd0, x=r_m))
                for i_sol in range(len(sol_hist) - 1)
        ]

        return  np.sum((np.array(exp_data) - np.array(sim_data)) ** 2)

# %% [markdown]
# The execution time of each simulation: around 2 minutes

# %%
from optuna.pruners import MedianPruner

# Each trial runs 7 sequential 30-000 s ODE integrations -- expect a few
# minutes of wall time per trial. Pick a budget you can afford. The
# objective above creates its own ccl() per trial, so n_jobs > 1 is safe.
study = optuna.create_study(direction="minimize", pruner=MedianPruner())
study.optimize(objective, n_trials=1000, timeout=3600*8, n_jobs=4)

print("Best parameters:", study.best_params)
print("Best objective:", study.best_value)
# Out:
# [I 2026-08-04 09:30:54,792] A new study created in memory with name: no-name-b1c740af-978c-4be2-a6fe-f0631ee2a610
# [I 2026-08-04 09:37:00,512] Trial 2 finished with value: 2.194825 and parameters: {'krdp': 2.181806849177821e-11, 'k1': 3.464141495324264e-12, 'k2': 1.5194612394245452e-13, 'k3': 6.668959517832572e-16, 'k4_ref': 8.943720594110403e-20}. Best is trial 2 with value: 2.194825.
# [I 2026-08-04 09:43:19,336] Trial 4 finished with value: 2.194825 and parameters: {'krdp': 2.376344872226038e-13, 'k1': 4.6658608891580146e-17, 'k2': 7.053868795304732e-16, 'k3': 7.084185481907357e-15, 'k4_ref': 1.2599628596257984e-19}. Best is trial 2 with value: 2.194825.
# [I 2026-08-04 09:57:05,828] Trial 1 finished with value: 2.194825 and parameters: {'krdp': 1.7768224012576372e-13, 'k1': 3.7567614616811924e-15, 'k2': 2.117480803600408e-12, 'k3': 7.084751389014067e-14, 'k4_ref': 5.341888816110432e-19}. Best is trial 2 with value: 2.194825.
# [I 2026-08-04 10:03:22,273] Trial 6 finished with value: 2.194825 and parameters: {'krdp': 1.2504238381313641e-08, 'k1': 6.498421667664766e-12, 'k2': 7.398591006360674e-16, 'k3': 3.7506424669069104e-15, 'k4_ref': 2.1144338872555787e-20}. Best is trial 2 with value: 2.194825.
# [I 2026-08-04 10:18:38,899] Trial 3 finished with value: 2.194825 and parameters: {'krdp': 7.258430907806816e-08, 'k1': 9.419381414430906e-12, 'k2': 7.152686224877117e-12, 'k3': 6.096770998495093e-17, 'k4_ref': 5.228423241485603e-19}. Best is trial 2 with value: 2.194825.
# [I 2026-08-04 10:21:15,655] Trial 7 finished with value: 2.194825 and parameters: {'krdp': 1.5714854251899403e-13, 'k1': 4.343591540776169e-17, 'k2': 6.637596632721461e-13, 'k3': 9.376013807301605e-15, 'k4_ref': 1.2504702757634818e-20}. Best is trial 2 with value: 2.194825.
# [I 2026-08-04 10:22:48,898] Trial 5 finished with value: 0.8688038634137563 and parameters: {'krdp': 9.536638139323836e-10, 'k1': 3.9638008872963995e-12, 'k2': 9.13449009961683e-12, 'k3': 4.0679608036939533e-14, 'k4_ref': 5.0817892628435557e-23}. Best is trial 5 with value: 0.8688038634137563.
# [I 2026-08-04 10:33:11,258] Trial 8 finished with value: 0.2382480304304075 and parameters: {'krdp': 2.9315721013469103e-12, 'k1': 3.2291499340268675e-15, 'k2': 9.153871753338328e-13, 'k3': 5.945304258594908e-16, 'k4_ref': 2.6841354783977845e-23}. Best is trial 8 with value: 0.2382480304304075.
# [I 2026-08-04 10:46:09,414] Trial 10 finished with value: 2.194825 and parameters: {'krdp': 4.734724744008402e-10, 'k1': 6.554262617149448e-14, 'k2': 2.197316360320357e-15, 'k3': 1.3046318873690815e-14, 'k4_ref': 2.0170562032907251e-19}. Best is trial 8 with value: 0.2382480304304075.
# [I 2026-08-04 10:49:05,765] Trial 9 finished with value: 2.194825 and parameters: {'krdp': 2.695718839675612e-09, 'k1': 3.107889540984631e-17, 'k2': 1.393529955659316e-14, 'k3': 1.178821250969442e-14, 'k4_ref': 2.2325073781180393e-19}. Best is trial 8 with value: 0.2382480304304075.
# [I 2026-08-04 10:49:07,603] Trial 13 finished with value: 0.5712673717101895 and parameters: {'krdp': 1.96561868552137e-11, 'k1': 2.0378697118763275e-15, 'k2': 1.1418475399308566e-17, 'k3': 1.1841976968195319e-17, 'k4_ref': 1.2733205377502487e-24}. Best is trial 8 with value: 0.2382480304304075.
# [I 2026-08-04 10:49:09,934] Trial 14 finished with value: 0.4369154258581901 and parameters: {'krdp': 9.75080642808942e-12, 'k1': 3.115245875814056e-15, 'k2': 1.1770498331655105e-17, 'k3': 1.1035383271604738e-17, 'k4_ref': 1.6368189244715738e-24}. Best is trial 8 with value: 0.2382480304304075.
# [I 2026-08-04 10:49:18,282] Trial 15 finished with value: 0.43748709685802656 and parameters: {'krdp': 6.360620936698706e-12, 'k1': 2.013582505374884e-15, 'k2': 1.753656301545585e-17, 'k3': 2.741185516984955e-16, 'k4_ref': 1.0143647290831812e-23}. Best is trial 8 with value: 0.2382480304304075.
# [I 2026-08-04 10:50:09,625] Trial 11 finished with value: 2.193220299106945 and parameters: {'krdp': 3.266961266420657e-12, 'k1': 2.2227057057594764e-15, 'k2': 8.320249029851015e-13, 'k3': 2.2269054749624086e-16, 'k4_ref': 1.982248332548186e-21}. Best is trial 8 with value: 0.2382480304304075.
# [I 2026-08-04 10:51:02,967] Trial 0 finished with value: 2.194825 and parameters: {'krdp': 1.6535976201069005e-12, 'k1': 1.4377988376364785e-12, 'k2': 5.545737846249152e-13, 'k3': 1.0193145497402579e-17, 'k4_ref': 4.605456905330854e-21}. Best is trial 8 with value: 0.2382480304304075.
# [I 2026-08-04 10:51:20,986] Trial 18 finished with value: 1.485356865474165 and parameters: {'krdp': 1.0746986088921025e-10, 'k1': 2.5988532670859394e-14, 'k2': 1.0001449323090946e-16, 'k3': 4.6031267210290764e-17, 'k4_ref': 1.5130708645909193e-22}. Best is trial 8 with value: 0.2382480304304075.
# [I 2026-08-04 10:59:13,866] Trial 16 finished with value: 2.1469414456951528 and parameters: {'krdp': 2.125258585790389e-12, 'k1': 4.378369328882446e-14, 'k2': 2.557636058703391e-14, 'k3': 2.349133938515954e-17, 'k4_ref': 1.5864309890271334e-22}. Best is trial 8 with value: 0.2382480304304075.
# [I 2026-08-04 11:05:21,509] Trial 19 finished with value: 0.9259214636691886 and parameters: {'krdp': 9.576672122228728e-13, 'k1': 4.333734826105941e-16, 'k2': 3.605199934878817e-14, 'k3': 1.2976959556729399e-15, 'k4_ref': 1.0817780574426634e-24}. Best is trial 8 with value: 0.2382480304304075.
# [I 2026-08-04 11:05:32,599] Trial 21 finished with value: 0.26213585508893783 and parameters: {'krdp': 4.7939433228885025e-11, 'k1': 2.0784872509750934e-16, 'k2': 8.276872542095318e-17, 'k3': 1.4445635458950324e-16, 'k4_ref': 7.36986181286617e-24}. Best is trial 8 with value: 0.2382480304304075.
# [I 2026-08-04 11:05:48,464] Trial 22 finished with value: 1.1447438842336324 and parameters: {'krdp': 5.5631453704389823e-11, 'k1': 2.5573340213567405e-16, 'k2': 1.0848066182263734e-16, 'k3': 1.5355581233535639e-16, 'k4_ref': 1.356784767390893e-23}. Best is trial 8 with value: 0.2382480304304075.
# [I 2026-08-04 11:16:12,949] Trial 12 finished with value: 2.194825 and parameters: {'krdp': 6.328265728413514e-13, 'k1': 3.662121572835331e-17, 'k2': 2.1547086809218445e-13, 'k3': 2.0008424839100387e-17, 'k4_ref': 3.954877760752969e-19}. Best is trial 8 with value: 0.2382480304304075.
# [I 2026-08-04 11:16:27,739] Trial 24 finished with value: 0.4434427145916417 and parameters: {'krdp': 9.105816980824527e-12, 'k1': 3.638174735390574e-16, 'k2': 6.965154755937962e-17, 'k3': 7.39617790021786e-16, 'k4_ref': 4.9870841411015944e-24}. Best is trial 8 with value: 0.2382480304304075.
# [I 2026-08-04 11:16:55,777] Trial 25 finished with value: 1.837046734941292 and parameters: {'krdp': 1.3248614030847715e-10, 'k1': 1.600151479153913e-14, 'k2': 3.344411917398333e-17, 'k3': 7.823064770562725e-17, 'k4_ref': 3.5529382656812334e-23}. Best is trial 8 with value: 0.2382480304304075.
# [I 2026-08-04 11:17:14,524] Trial 26 finished with value: 0.12172479647171489 and parameters: {'krdp': 4.151095664392044e-11, 'k1': 2.4565141600517257e-13, 'k2': 4.925692483560418e-16, 'k3': 1.84653475188853e-15, 'k4_ref': 3.8223726509841124e-24}. Best is trial 26 with value: 0.12172479647171489.
# [I 2026-08-04 11:21:28,602] Trial 17 finished with value: 1.9060457568940938 and parameters: {'krdp': 9.611035894938533e-11, 'k1': 2.7650578797143977e-14, 'k2': 3.861556151321053e-14, 'k3': 1.747039447146973e-17, 'k4_ref': 1.5403937116744588e-22}. Best is trial 26 with value: 0.12172479647171489.
# [I 2026-08-04 11:21:39,195] Trial 27 finished with value: 2.1948252965829784 and parameters: {'krdp': 3.177596770584233e-10, 'k1': 2.4961526236224357e-13, 'k2': 3.7229363406786575e-16, 'k3': 2.169156841517378e-15, 'k4_ref': 3.936320118774226e-22}. Best is trial 26 with value: 0.12172479647171489.
# [I 2026-08-04 11:21:49,040] Trial 28 finished with value: 0.07543439888033687 and parameters: {'krdp': 4.768372203052809e-10, 'k1': 1.2248842728802697e-16, 'k2': 4.197523730353167e-16, 'k3': 1.441160840316608e-15, 'k4_ref': 4.3060124728022705e-24}. Best is trial 28 with value: 0.07543439888033687.
# [I 2026-08-04 11:22:11,713] Trial 20 finished with value: 0.8947594789956506 and parameters: {'krdp': 9.640293774693884e-11, 'k1': 2.3841966736608544e-16, 'k2': 3.4205035559650103e-14, 'k3': 5.657369121688721e-16, 'k4_ref': 1.1295111891268995e-24}. Best is trial 28 with value: 0.07543439888033687.
# [I 2026-08-04 11:25:48,540] Trial 23 finished with value: 2.1947062970778113 and parameters: {'krdp': 1.1096063627424681e-10, 'k1': 2.327603092617555e-16, 'k2': 5.149304963305932e-15, 'k3': 1.1660668503647194e-15, 'k4_ref': 8.62887044023209e-22}. Best is trial 28 with value: 0.07543439888033687.
# [I 2026-08-04 11:27:26,227] Trial 30 finished with value: 0.20720063964892932 and parameters: {'krdp': 1.54792835934252e-09, 'k1': 6.073139147581304e-13, 'k2': 3.798318553441768e-15, 'k3': 5.998349524089549e-16, 'k4_ref': 2.1203862361259656e-23}. Best is trial 28 with value: 0.07543439888033687.
# [I 2026-08-04 11:28:28,719] Trial 32 finished with value: 0.37783372720520875 and parameters: {'krdp': 4.02402015328525e-09, 'k1': 5.234489948190083e-13, 'k2': 2.7175091930481242e-15, 'k3': 3.4813657465056542e-15, 'k4_ref': 2.8896148579283075e-23}. Best is trial 28 with value: 0.07543439888033687.
# [I 2026-08-04 11:28:36,467] Trial 34 finished with value: 0.0815079884283702 and parameters: {'krdp': 1.7084123480259366e-09, 'k1': 7.656384498217589e-13, 'k2': 2.661286319210428e-16, 'k3': 3.6012705281058433e-16, 'k4_ref': 4.0872122257838636e-24}. Best is trial 28 with value: 0.07543439888033687.
# [I 2026-08-04 11:28:43,830] Trial 35 finished with value: 0.1441984164551023 and parameters: {'krdp': 2.8480055257315227e-09, 'k1': 9.699229119788496e-13, 'k2': 3.404969972862523e-16, 'k3': 1.4840504435823935e-15, 'k4_ref': 3.4404525613266826e-24}. Best is trial 28 with value: 0.07543439888033687.
# [I 2026-08-04 11:28:53,250] Trial 36 finished with value: 0.11399758138694063 and parameters: {'krdp': 9.374234618269108e-09, 'k1': 1.4443485377549576e-13, 'k2': 2.713943994952497e-16, 'k3': 1.8644012516653444e-15, 'k4_ref': 3.317827770258571e-24}. Best is trial 28 with value: 0.07543439888033687.
# [I 2026-08-04 11:29:08,301] Trial 37 finished with value: 0.1386813815506011 and parameters: {'krdp': 1.5927891302689067e-08, 'k1': 1.1190243922203436e-13, 'k2': 3.2872166228509195e-16, 'k3': 4.017512142827933e-15, 'k4_ref': 3.260704882676268e-24}. Best is trial 28 with value: 0.07543439888033687.
# [I 2026-08-04 11:29:27,373] Trial 33 finished with value: 0.46084501863078986 and parameters: {'krdp': 2.915581442603607e-09, 'k1': 5.997799831067534e-13, 'k2': 3.2956834320432362e-15, 'k3': 3.2069004800900524e-15, 'k4_ref': 3.145320671965356e-24}. Best is trial 28 with value: 0.07543439888033687.
# [I 2026-08-04 11:30:12,827] Trial 29 finished with value: 0.5072299354230757 and parameters: {'krdp': 5.008626587185435e-11, 'k1': 3.490552762065184e-13, 'k2': 5.029427062194599e-15, 'k3': 5.596879675617184e-16, 'k4_ref': 4.928374082767772e-24}. Best is trial 28 with value: 0.07543439888033687.
# [I 2026-08-04 11:30:30,982] Trial 38 finished with value: 0.06431642272692038 and parameters: {'krdp': 1.13052741707569e-08, 'k1': 2.171883895418131e-12, 'k2': 1.2318447222882877e-15, 'k3': 3.4671001465851357e-16, 'k4_ref': 2.9761651014555165e-24}. Best is trial 38 with value: 0.06431642272692038.
# [I 2026-08-04 11:30:40,390] Trial 31 finished with value: 0.3181583075568941 and parameters: {'krdp': 2.8821400720440285e-09, 'k1': 2.6619736469755717e-13, 'k2': 4.3805907082435565e-15, 'k3': 2.510980322922088e-15, 'k4_ref': 3.4035286952825246e-24}. Best is trial 38 with value: 0.06431642272692038.
# [I 2026-08-04 11:31:00,929] Trial 39 finished with value: 1.6256894579011638 and parameters: {'krdp': 8.96364202577822e-08, 'k1': 2.065761180777283e-13, 'k2': 1.1495146624620587e-15, 'k3': 3.476727176726656e-16, 'k4_ref': 7.5239614891837e-23}. Best is trial 38 with value: 0.06431642272692038.
# [I 2026-08-04 11:31:09,281] Trial 41 finished with value: 0.6067543172513387 and parameters: {'krdp': 5.5856092130698425e-08, 'k1': 2.1364848467146977e-12, 'k2': 9.593978000242223e-16, 'k3': 1.0008983953598952e-15, 'k4_ref': 1.2715685061710923e-23}. Best is trial 38 with value: 0.06431642272692038.
# [I 2026-08-04 11:31:14,469] Trial 43 finished with value: 0.02878745011052886 and parameters: {'krdp': 2.7029177738443443e-08, 'k1': 2.3134137925787836e-12, 'k2': 1.7001131799421673e-16, 'k3': 5.95006149819218e-15, 'k4_ref': 1.0916903338643673e-23}. Best is trial 43 with value: 0.02878745011052886.
# [I 2026-08-04 11:31:16,963] Trial 44 finished with value: 0.20665445336203958 and parameters: {'krdp': 1.0698633567244438e-08, 'k1': 1.442164842895541e-17, 'k2': 1.845074036864473e-16, 'k3': 6.5426265785093994e-15, 'k4_ref': 1.8799161980179554e-24}. Best is trial 43 with value: 0.02878745011052886.
# [I 2026-08-04 11:31:18,506] Trial 40 finished with value: 1.8136249745530697 and parameters: {'krdp': 1.45564080493219e-08, 'k1': 1.1521158204246937e-17, 'k2': 1.0040684009200633e-15, 'k3': 1.934700966354808e-14, 'k4_ref': 7.824637449296937e-23}. Best is trial 43 with value: 0.02878745011052886.
# [I 2026-08-04 11:31:24,249] Trial 45 finished with value: 0.06450433481430767 and parameters: {'krdp': 1.2890131112922739e-08, 'k1': 2.048061171758176e-12, 'k2': 1.7926783078344488e-16, 'k3': 2.6496190528127494e-14, 'k4_ref': 7.853350646502312e-24}. Best is trial 43 with value: 0.02878745011052886.
# [I 2026-08-04 11:31:26,574] Trial 46 finished with value: 0.2586762481079469 and parameters: {'krdp': 2.4938170681850583e-08, 'k1': 4.463544832617276e-12, 'k2': 4.2400306756996284e-17, 'k3': 2.3980126168674752e-14, 'k4_ref': 8.593381161342133e-24}. Best is trial 43 with value: 0.02878745011052886.
# [I 2026-08-04 11:31:32,332] Trial 47 finished with value: 0.7750818388007227 and parameters: {'krdp': 3.342424219041048e-08, 'k1': 4.824009671218536e-12, 'k2': 1.969985080871752e-16, 'k3': 6.561149262283e-14, 'k4_ref': 9.002163713211045e-24}. Best is trial 43 with value: 0.02878745011052886.
# [I 2026-08-04 11:31:36,518] Trial 48 finished with value: 0.5361959832633122 and parameters: {'krdp': 3.7011856418220964e-08, 'k1': 4.326785799988048e-12, 'k2': 3.5443880795554557e-17, 'k3': 5.948251253455348e-15, 'k4_ref': 7.912788004009243e-24}. Best is trial 43 with value: 0.02878745011052886.
# [I 2026-08-04 11:31:56,288] Trial 49 finished with value: 1.4446887598588838 and parameters: {'krdp': 3.7206587597424726e-08, 'k1': 1.6568943159613662e-12, 'k2': 1.6943910403959317e-16, 'k3': 7.243549535499828e-14, 'k4_ref': 1.908854312832412e-23}. Best is trial 43 with value: 0.02878745011052886.
# [I 2026-08-04 11:32:15,707] Trial 42 finished with value: 1.9458709641257836 and parameters: {'krdp': 3.141426696461651e-08, 'k1': 2.297345543405523e-12, 'k2': 1.2165979510012984e-15, 'k3': 3.5960981653008814e-16, 'k4_ref': 8.042008656083057e-23}. Best is trial 43 with value: 0.02878745011052886.
# [I 2026-08-04 11:32:34,883] Trial 50 finished with value: 0.6866271124523973 and parameters: {'krdp': 6.006967913726371e-09, 'k1': 1.9674502886118214e-12, 'k2': 1.6402363933950862e-15, 'k3': 9.301396171328014e-14, 'k4_ref': 2.0518976410656112e-23}. Best is trial 43 with value: 0.02878745011052886.
# [I 2026-08-04 11:32:37,650] Trial 52 finished with value: 1.8805510911843295 and parameters: {'krdp': 6.269923056265495e-09, 'k1': 8.40431440070064e-12, 'k2': 6.750775257417964e-16, 'k3': 3.540860492980385e-14, 'k4_ref': 4.6827130589902805e-23}. Best is trial 43 with value: 0.02878745011052886.
# [I 2026-08-04 11:32:42,138] Trial 55 finished with value: 0.049294327456207945 and parameters: {'krdp': 9.406552451752158e-10, 'k1': 1.0416641243036401e-12, 'k2': 2.1887694834752405e-16, 'k3': 1.6992631052017256e-14, 'k4_ref': 2.3028588440663888e-24}. Best is trial 43 with value: 0.02878745011052886.
# [I 2026-08-04 11:32:51,184] Trial 51 finished with value: 0.38508546175849945 and parameters: {'krdp': 9.429426051140833e-10, 'k1': 2.0150229277502294e-12, 'k2': 1.82619749587981e-15, 'k3': 5.837682708600903e-14, 'k4_ref': 1.916308324033163e-23}. Best is trial 43 with value: 0.02878745011052886.
# [I 2026-08-04 11:32:56,972] Trial 54 finished with value: 0.09338662438464289 and parameters: {'krdp': 8.117917779514702e-09, 'k1': 9.95925045432344e-12, 'k2': 6.48612355377731e-16, 'k3': 1.850606410312677e-14, 'k4_ref': 2.2658199488522714e-24}. Best is trial 43 with value: 0.02878745011052886.
# [I 2026-08-04 11:32:57,188] Trial 57 finished with value: 0.025765630852922702 and parameters: {'krdp': 4.682782776528097e-10, 'k1': 1.1417030458202958e-12, 'k2': 5.5376924438280165e-17, 'k3': 1.455420398351098e-14, 'k4_ref': 2.202548806878954e-24}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 11:33:01,967] Trial 58 finished with value: 0.6683229696964381 and parameters: {'krdp': 3.528536353939261e-10, 'k1': 9.326559936357125e-13, 'k2': 1.488602688474201e-16, 'k3': 9.523181668592994e-15, 'k4_ref': 1.9178384265408935e-24}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 11:33:02,383] Trial 59 finished with value: 0.26861988006095816 and parameters: {'krdp': 4.889152590816952e-10, 'k1': 1.0682468980235628e-12, 'k2': 2.1137428277652182e-17, 'k3': 9.497823075071842e-15, 'k4_ref': 1.8124328310763226e-24}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 11:33:04,141] Trial 60 finished with value: 0.4739830927899884 and parameters: {'krdp': 7.493967456690363e-10, 'k1': 6.5779237454377195e-15, 'k2': 5.230062696323285e-17, 'k3': 3.125401146772339e-14, 'k4_ref': 1.032422424619461e-24}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 11:33:04,493] Trial 56 finished with value: 0.1780066945860883 and parameters: {'krdp': 7.726270451440498e-10, 'k1': 1.2145759428781506e-12, 'k2': 5.909579311284766e-16, 'k3': 1.4149043305039081e-14, 'k4_ref': 2.2441597853426507e-24}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 11:33:08,959] Trial 61 finished with value: 0.050187564230338995 and parameters: {'krdp': 8.7012632358887e-10, 'k1': 1.035319751156353e-14, 'k2': 6.321751900638859e-17, 'k3': 1.4687728329494547e-14, 'k4_ref': 5.558572863228275e-24}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 11:33:16,898] Trial 64 finished with value: 0.08062288577120762 and parameters: {'krdp': 2.0241879627804152e-10, 'k1': 1.0155225241012525e-15, 'k2': 2.261865412166741e-17, 'k3': 2.931841550709719e-14, 'k4_ref': 6.45222245917194e-24}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 11:33:16,975] Trial 63 finished with value: 0.18271273301878593 and parameters: {'krdp': 2.0095685770220237e-10, 'k1': 2.9250754331163084e-12, 'k2': 2.1017595343362718e-17, 'k3': 5.033508079004692e-15, 'k4_ref': 6.660255183878333e-24}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 11:33:29,547] Trial 65 finished with value: 0.26722545326507724 and parameters: {'krdp': 1.4486562294033093e-09, 'k1': 3.3665048562337836e-12, 'k2': 7.000262346775496e-17, 'k3': 4.785764876469988e-15, 'k4_ref': 5.478133303669587e-24}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 11:34:30,074] Trial 67 finished with value: 2.194825 and parameters: {'krdp': 5.713361960872223e-10, 'k1': 7.39023464797694e-15, 'k2': 1.1854373669644157e-16, 'k3': 1.5123854463408867e-14, 'k4_ref': 9.805203908356694e-21}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 11:34:33,141] Trial 66 finished with value: 2.1948249999999994 and parameters: {'krdp': 1.3437625619665201e-09, 'k1': 7.504108879823439e-14, 'k2': 1.0154372912143417e-16, 'k3': 1.78011268836439e-14, 'k4_ref': 3.437234622129918e-20}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 11:34:49,742] Trial 69 finished with value: 1.162966956833518 and parameters: {'krdp': 2.9212721143066143e-10, 'k1': 8.671953590222509e-17, 'k2': 6.058096068587445e-17, 'k3': 4.396274351999538e-14, 'k4_ref': 1.3382146122006845e-23}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 11:47:21,422] Trial 53 finished with value: 0.6616221919336632 and parameters: {'krdp': 5.678861532064842e-09, 'k1': 8.504306801220222e-12, 'k2': 8.658260300915265e-15, 'k3': 3.3662430308284926e-14, 'k4_ref': 1.8928709259303757e-24}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 11:47:44,564] Trial 71 finished with value: 0.75500470660997 and parameters: {'krdp': 5.955638766960099e-08, 'k1': 9.415870998812641e-16, 'k2': 4.803223194962033e-16, 'k3': 1.1517531021251631e-14, 'k4_ref': 1.1781190650874372e-23}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 11:47:48,531] Trial 72 finished with value: 0.42034716623639135 and parameters: {'krdp': 4.195517277481889e-09, 'k1': 4.054216121850729e-13, 'k2': 3.1942128955118645e-17, 'k3': 7.339106003159559e-15, 'k4_ref': 1.3809078580750307e-24}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 11:48:00,020] Trial 73 finished with value: 1.3301728911056383 and parameters: {'krdp': 1.9884078894642866e-08, 'k1': 9.761957008680072e-15, 'k2': 1.0250048569737543e-17, 'k3': 2.3911121875341346e-14, 'k4_ref': 3.2200461149322315e-23}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 11:48:11,930] Trial 74 finished with value: 0.10864631526056742 and parameters: {'krdp': 1.8815791574387718e-10, 'k1': 9.127294766447839e-16, 'k2': 2.1866694345097246e-16, 'k3': 2.5132186143913656e-14, 'k4_ref': 5.804768817131347e-24}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 11:48:18,974] Trial 75 finished with value: 0.09104616376719481 and parameters: {'krdp': 1.5737948699145238e-10, 'k1': 8.915546384147544e-16, 'k2': 2.3398480175058735e-17, 'k3': 1.2000690883600212e-14, 'k4_ref': 2.6797189482095804e-24}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 11:48:24,709] Trial 76 finished with value: 0.37238780275602323 and parameters: {'krdp': 2.114371108819965e-09, 'k1': 8.740096263581457e-17, 'k2': 1.562583716859911e-17, 'k3': 8.229373567365963e-15, 'k4_ref': 4.873748825385993e-24}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 11:48:31,991] Trial 77 finished with value: 0.3835265592233801 and parameters: {'krdp': 7.759508067777933e-11, 'k1': 1.2344081099146447e-12, 'k2': 1.0454875601737209e-16, 'k3': 3.9737388355182773e-14, 'k4_ref': 8.13496439401827e-24}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 11:48:50,725] Trial 78 finished with value: 1.4919277481906925 and parameters: {'krdp': 2.5645213588392998e-11, 'k1': 9.506709390146342e-17, 'k2': 5.596616659284545e-17, 'k3': 4.792032680915798e-14, 'k4_ref': 1.5924885678412308e-23}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 11:49:06,331] Trial 79 finished with value: 0.2872834436768323 and parameters: {'krdp': 2.891387520189078e-10, 'k1': 5.832147405287434e-16, 'k2': 3.7423815457571933e-16, 'k3': 1.5281006387310813e-16, 'k4_ref': 4.749210036712511e-24}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 11:49:08,975] Trial 80 finished with value: 0.44804911704185124 and parameters: {'krdp': 6.362709148378089e-10, 'k1': 1.53064992790219e-16, 'k2': 1.5237848275105696e-16, 'k3': 2.8089607276867e-15, 'k4_ref': 1.3008702417134868e-24}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 11:52:30,648] Trial 68 finished with value: 0.030960147827869593 and parameters: {'krdp': 1.317323341711851e-09, 'k1': 9.808105421797155e-17, 'k2': 8.393358045789383e-15, 'k3': 7.966165842457924e-15, 'k4_ref': 1.2967081948650175e-23}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 11:57:45,568] Trial 70 finished with value: 0.6405618118190252 and parameters: {'krdp': 1.957796288722379e-08, 'k1': 9.38599076090644e-16, 'k2': 1.402368904548293e-14, 'k3': 8.81146564894079e-15, 'k4_ref': 1.3979988401783149e-24}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 12:04:53,752] Trial 81 finished with value: 0.9464286393415546 and parameters: {'krdp': 1.0877446334696235e-09, 'k1': 5.957516284468688e-12, 'k2': 1.998880783711629e-13, 'k3': 2.815839796896583e-14, 'k4_ref': 2.63517874940547e-24}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 12:13:34,308] Trial 83 finished with value: 0.1854951419901369 and parameters: {'krdp': 1.326686519652107e-09, 'k1': 3.594109743891926e-17, 'k2': 7.725971104925073e-15, 'k3': 6.037894926576527e-17, 'k4_ref': 1.0082660982743247e-23}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 12:14:04,504] Trial 62 finished with value: 0.5286143420092708 and parameters: {'krdp': 2.0419840077199716e-10, 'k1': 1.0789603744656063e-15, 'k2': 2.151833411137119e-12, 'k3': 1.6007409515825038e-14, 'k4_ref': 5.8190575830335976e-24}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 12:15:27,296] Trial 82 finished with value: 0.13495292023112956 and parameters: {'krdp': 1.0912960529715776e-09, 'k1': 3.783819431941854e-17, 'k2': 1.7986637499982466e-14, 'k3': 8.27740206511312e-16, 'k4_ref': 9.885381840526887e-24}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 12:15:46,940] Trial 87 finished with value: 1.5393909674169792 and parameters: {'krdp': 3.8078615665037646e-10, 'k1': 2.9795426129344385e-14, 'k2': 8.128678710968559e-17, 'k3': 2.2663476671647418e-14, 'k4_ref': 4.2366156911848963e-23}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 12:16:00,221] Trial 88 finished with value: 0.6048693713892227 and parameters: {'krdp': 2.785758283195133e-13, 'k1': 2.0280272561449374e-17, 'k2': 2.913419511609858e-17, 'k3': 1.127191293245995e-16, 'k4_ref': 2.7646546724554183e-23}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 12:16:08,485] Trial 89 finished with value: 0.09314910740561674 and parameters: {'krdp': 5.052219489682936e-10, 'k1': 7.033098892188231e-17, 'k2': 2.7114648422587326e-16, 'k3': 2.242404403536749e-16, 'k4_ref': 3.730115798151784e-24}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 12:17:35,471] Trial 90 finished with value: 2.1948249999999305 and parameters: {'krdp': 2.181462252943661e-09, 'k1': 1.29207321524757e-16, 'k2': 3.9068711847318344e-17, 'k3': 1.0570158413893542e-14, 'k4_ref': 8.344291968283359e-19}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 12:24:18,502] Trial 84 finished with value: 0.5428077856367438 and parameters: {'krdp': 3.8231064416478004e-10, 'k1': 3.3634635716743735e-17, 'k2': 1.4745870162131182e-12, 'k3': 1.826741900945082e-14, 'k4_ref': 1.0982093841554697e-23}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 12:24:33,707] Trial 92 finished with value: 0.3830390047871241 and parameters: {'krdp': 3.92838561503613e-09, 'k1': 5.863864451790023e-17, 'k2': 1.333018910898845e-16, 'k3': 5.8862438297979775e-15, 'k4_ref': 1.5639956970497825e-23}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 12:42:33,858] Trial 85 finished with value: 0.11805309624598635 and parameters: {'krdp': 4.5832537724196907e-10, 'k1': 1.6322194534357645e-17, 'k2': 1.559021281340247e-12, 'k3': 1.851925679803636e-14, 'k4_ref': 4.791981959819135e-23}. Best is trial 57 with value: 0.025765630852922702.
# [I 2026-08-04 12:42:45,256] Trial 94 finished with value: 0.02193860355497274 and parameters: {'krdp': 1.2014867511585375e-08, 'k1': 5.180453358688396e-13, 'k2': 2.4125523468447415e-16, 'k3': 3.5507672737312897e-16, 'k4_ref': 4.2867099949209266e-24}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 12:43:02,531] Trial 95 finished with value: 0.06562516633472507 and parameters: {'krdp': 1.3188886080556552e-08, 'k1': 4.883413398859046e-13, 'k2': 3.935080110240682e-16, 'k3': 3.9490756270747124e-16, 'k4_ref': 7.013311514190824e-24}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 12:43:41,943] Trial 96 finished with value: 0.3031369557619622 and parameters: {'krdp': 1.2157063004509887e-08, 'k1': 7.020538732352745e-13, 'k2': 9.45576101676052e-16, 'k3': 4.015622730353107e-16, 'k4_ref': 2.9741484475912944e-24}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 12:43:59,344] Trial 97 finished with value: 0.11521680374055553 and parameters: {'krdp': 7.789890269210923e-09, 'k1': 4.4926225762661826e-13, 'k2': 4.0425167442947105e-16, 'k3': 2.5581387504656755e-16, 'k4_ref': 4.090233318497137e-24}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 12:44:20,763] Trial 98 finished with value: 0.40339540150817454 and parameters: {'krdp': 5.2882174987673926e-08, 'k1': 3.391160319891437e-13, 'k2': 2.3216864214055817e-16, 'k3': 4.745453105118471e-16, 'k4_ref': 7.157837630516415e-24}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 12:47:30,459] Trial 91 finished with value: 0.5637134267068503 and parameters: {'krdp': 3.6958834512005027e-09, 'k1': 3.866604870347668e-16, 'k2': 4.4186526912043845e-14, 'k3': 6.3037102329211275e-15, 'k4_ref': 2.6635672962215993e-24}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 12:49:27,270] Trial 100 finished with value: 0.4813056866763378 and parameters: {'krdp': 9.734007159965387e-08, 'k1': 2.9949213727250856e-12, 'k2': 1.585819269882489e-15, 'k3': 1.9262780495805712e-16, 'k4_ref': 1.0266342255912842e-24}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 12:50:03,374] Trial 101 finished with value: 0.9873116404426332 and parameters: {'krdp': 2.1941948607221273e-08, 'k1': 1.5266240367448002e-13, 'k2': 5.344875961782447e-16, 'k3': 3.1062938644817107e-16, 'k4_ref': 2.102071461176995e-23}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 12:52:38,292] Trial 102 finished with value: 0.07889990741069683 and parameters: {'krdp': 1.2530123694997496e-08, 'k1': 1.8137951202376755e-12, 'k2': 2.4024647798332477e-15, 'k3': 9.926523019507343e-16, 'k4_ref': 4.5240461819074004e-24}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 12:52:47,924] Trial 103 finished with value: 0.2996628998615325 and parameters: {'krdp': 1.585828272587229e-08, 'k1': 1.4104390754289122e-12, 'k2': 7.837276898924923e-16, 'k3': 4.600041209241137e-16, 'k4_ref': 1.705794226954635e-24}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 12:54:41,758] Trial 104 finished with value: 0.48632852401887117 and parameters: {'krdp': 1.1251690937470345e-08, 'k1': 8.40118010902906e-13, 'k2': 2.34401337875589e-15, 'k3': 9.473892868192039e-16, 'k4_ref': 4.370393457903349e-24}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 12:56:07,206] Trial 93 finished with value: 0.1407849481051706 and parameters: {'krdp': 7.509170543624415e-11, 'k1': 2.8702207958018887e-12, 'k2': 6.320020538501092e-14, 'k3': 1.3102863246877167e-14, 'k4_ref': 6.938221996733714e-24}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 12:58:12,822] Trial 106 finished with value: 0.21259409346737565 and parameters: {'krdp': 2.861030744521077e-08, 'k1': 5.741360648682507e-13, 'k2': 3.0529176090812748e-15, 'k3': 1.6394096826314834e-15, 'k4_ref': 2.2468792319606094e-24}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 13:10:52,470] Trial 107 finished with value: 0.3828652118333553 and parameters: {'krdp': 6.485227829599903e-09, 'k1': 1.8409331773973158e-12, 'k2': 5.967947213690615e-15, 'k3': 1.1077149985719952e-15, 'k4_ref': 3.684051472627505e-24}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 13:11:04,141] Trial 108 finished with value: 0.41817622609869803 and parameters: {'krdp': 4.043058816587518e-08, 'k1': 1.5375360765233534e-12, 'k2': 2.874702278163216e-16, 'k3': 7.746969366667411e-16, 'k4_ref': 9.051253107943297e-24}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 13:11:18,752] Trial 86 finished with value: 0.4062420813765813 and parameters: {'krdp': 4.0040780317527535e-10, 'k1': 1.4678062730931501e-16, 'k2': 4.952670931971304e-14, 'k3': 2.277399186212367e-14, 'k4_ref': 3.947134874686567e-24}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 13:11:50,602] Trial 109 finished with value: 0.17939251290154237 and parameters: {'krdp': 4.76596964158687e-09, 'k1': 2.42835936018326e-12, 'k2': 1.4829203680857067e-15, 'k3': 1.3537698638962747e-15, 'k4_ref': 1.2947905485186007e-23}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 13:12:00,289] Trial 99 finished with value: 0.8051634840225097 and parameters: {'krdp': 2.6709067599607833e-08, 'k1': 1.6186217565503538e-13, 'k2': 5.250359303012567e-14, 'k3': 1.166336160600852e-15, 'k4_ref': 2.4815409729905864e-24}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 13:12:03,968] Trial 111 finished with value: 0.3392573825655587 and parameters: {'krdp': 9.056661903446621e-09, 'k1': 3.989507154773457e-12, 'k2': 1.8983698686803522e-16, 'k3': 5.070768180153332e-16, 'k4_ref': 5.623851434494946e-24}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 13:12:04,908] Trial 110 finished with value: 0.13619658127900597 and parameters: {'krdp': 1.970051919956562e-09, 'k1': 9.955192094780707e-13, 'k2': 1.30558573899224e-15, 'k3': 5.626861158620536e-16, 'k4_ref': 1.412081362290829e-23}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 13:12:14,526] Trial 112 finished with value: 0.05771446203707586 and parameters: {'krdp': 8.256514712918336e-10, 'k1': 6.4314574906452354e-12, 'k2': 4.153821535194528e-16, 'k3': 6.689841026982901e-16, 'k4_ref': 5.4648227327907775e-24}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 13:12:18,784] Trial 114 finished with value: 0.23868688861501985 and parameters: {'krdp': 8.325719647233605e-10, 'k1': 6.209299115787739e-12, 'k2': 5.261508906276468e-17, 'k3': 4.306010255796506e-15, 'k4_ref': 6.357289565858307e-24}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 13:12:22,171] Trial 113 finished with value: 0.7141154621120259 and parameters: {'krdp': 1.3618716453333714e-08, 'k1': 5.843247911115576e-12, 'k2': 8.986693171827601e-17, 'k3': 6.533757344354928e-16, 'k4_ref': 1.573140177410001e-23}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 13:12:29,670] Trial 116 finished with value: 0.20083329222212976 and parameters: {'krdp': 1.4744956896243444e-08, 'k1': 4.7371515641698e-12, 'k2': 4.673676836505443e-16, 'k3': 6.612682570670201e-16, 'k4_ref': 1.663757293929503e-24}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 13:12:30,726] Trial 115 finished with value: 0.2672294749717356 and parameters: {'krdp': 1.558696105338138e-08, 'k1': 6.948787481128587e-12, 'k2': 4.485973399505171e-16, 'k3': 2.806965160836313e-16, 'k4_ref': 7.57581615795604e-24}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 13:12:34,937] Trial 119 finished with value: 1.040197571056946 and parameters: {'krdp': 2.5053482557773515e-10, 'k1': 1.3666455811774195e-12, 'k2': 7.516762351899948e-16, 'k3': 8.791236869993448e-16, 'k4_ref': 3.321513339615169e-24}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 13:12:38,975] Trial 117 finished with value: 0.22403272052018658 and parameters: {'krdp': 1.9492561674861652e-08, 'k1': 1.3575674682121759e-12, 'k2': 4.454134170167412e-16, 'k3': 2.735306348487121e-16, 'k4_ref': 1.6485680073706297e-24}. Best is trial 94 with value: 0.02193860355497274.
# [I 2026-08-04 13:12:43,872] Trial 118 finished with value: 0.009221147074878724 and parameters: {'krdp': 2.8226646021166705e-09, 'k1': 1.3715580947637938e-12, 'k2': 3.0108026939438794e-16, 'k3': 8.574535000628898e-16, 'k4_ref': 3.104182600876405e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:12:48,122] Trial 120 finished with value: 0.5932837998111063 and parameters: {'krdp': 6.225430621548633e-10, 'k1': 2.5822650824145575e-12, 'k2': 1.3566443716261576e-16, 'k3': 1.4671731940026215e-14, 'k4_ref': 2.4945284591879604e-23}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:12:49,168] Trial 121 finished with value: 0.15625792941490071 and parameters: {'krdp': 3.271178688486773e-09, 'k1': 7.301422352635226e-13, 'k2': 1.533454802671767e-16, 'k3': 7.516243190631455e-15, 'k4_ref': 4.988387662985498e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:12:50,465] Trial 122 finished with value: 0.02470020964867931 and parameters: {'krdp': 2.3062011671491363e-09, 'k1': 7.361569652949556e-13, 'k2': 1.3999406398855215e-16, 'k3': 4.049354702686818e-16, 'k4_ref': 2.2329502736856043e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:12:51,410] Trial 125 finished with value: 1.040992243306785 and parameters: {'krdp': 2.4097067083382214e-09, 'k1': 3.323220275570688e-13, 'k2': 3.2983554907061054e-16, 'k3': 2.2717973685378524e-16, 'k4_ref': 2.1618832298549713e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:12:56,755] Trial 124 finished with value: 0.05379484530851362 and parameters: {'krdp': 2.5152040188941235e-09, 'k1': 2.949136174454775e-13, 'k2': 2.856835394861693e-16, 'k3': 2.1967658306035953e-15, 'k4_ref': 2.191607357168082e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:13:02,763] Trial 127 finished with value: 0.2643168959681293 and parameters: {'krdp': 1.7355832551399065e-09, 'k1': 4.3945309200908155e-13, 'k2': 2.5120663673239535e-16, 'k3': 3.742221493604762e-16, 'k4_ref': 1.4368060510026068e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:13:03,439] Trial 123 finished with value: 0.6196521288483979 and parameters: {'krdp': 2.6207328021218183e-09, 'k1': 7.501698783059004e-13, 'k2': 2.301524372475623e-16, 'k3': 4.0128255017968133e-16, 'k4_ref': 1.0208508831217419e-23}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:13:04,684] Trial 126 finished with value: 0.9949727654960749 and parameters: {'krdp': 1.6682425858030247e-09, 'k1': 5.550135409990889e-13, 'k2': 2.327232952025036e-16, 'k3': 3.5073110138558915e-16, 'k4_ref': 9.276246257771665e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:13:07,483] Trial 130 finished with value: 0.5514491317531599 and parameters: {'krdp': 1.1973826726425546e-09, 'k1': 2.350401701639752e-13, 'k2': 7.192028705919154e-17, 'k3': 2.3820180969058678e-15, 'k4_ref': 2.3318999109438485e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:13:08,044] Trial 128 finished with value: 0.08746175857624383 and parameters: {'krdp': 1.1420576921343637e-09, 'k1': 8.10830955787469e-14, 'k2': 7.306164639961162e-17, 'k3': 1.92931114531801e-15, 'k4_ref': 2.8277408518708796e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:13:08,754] Trial 129 finished with value: 0.02468596015151779 and parameters: {'krdp': 9.565987684212217e-10, 'k1': 8.121631454498544e-14, 'k2': 8.225726543703702e-17, 'k3': 1.8925956529062846e-16, 'k4_ref': 3.1997577587593193e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:13:11,710] Trial 133 finished with value: 0.12259340122938059 and parameters: {'krdp': 8.158213343681613e-10, 'k1': 1.5813998092745456e-14, 'k2': 1.0794473984829854e-16, 'k3': 1.8757468567894788e-16, 'k4_ref': 1.1726084132648821e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:13:14,626] Trial 131 finished with value: 0.04314299075186956 and parameters: {'krdp': 5.417256757353927e-09, 'k1': 1.124564041684311e-12, 'k2': 1.1132344844828336e-16, 'k3': 1.0534440096770467e-14, 'k4_ref': 2.8926723444555474e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:13:21,327] Trial 135 finished with value: 0.030006135682198145 and parameters: {'krdp': 5.464066383332435e-09, 'k1': 4.8506196188583305e-14, 'k2': 1.6845388195099733e-16, 'k3': 1.0312255768117098e-14, 'k4_ref': 2.8794154990155147e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:13:21,511] Trial 134 finished with value: 0.1038220137734234 and parameters: {'krdp': 7.651022133335202e-09, 'k1': 4.353945554763255e-14, 'k2': 1.5524447404432525e-16, 'k3': 1.0453798588507915e-14, 'k4_ref': 2.9573262693948318e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:13:26,186] Trial 137 finished with value: 0.10084481022979713 and parameters: {'krdp': 4.318461851841192e-09, 'k1': 5.090351430117095e-14, 'k2': 1.1561510949358526e-16, 'k3': 1.32687217328529e-16, 'k4_ref': 1.882982069071443e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:13:26,912] Trial 136 finished with value: 0.11048869091723935 and parameters: {'krdp': 5.003453842299049e-09, 'k1': 5.472850605156459e-14, 'k2': 4.457088889188661e-17, 'k3': 1.0430476202830702e-14, 'k4_ref': 3.3325366018473115e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:13:31,974] Trial 138 finished with value: 0.03425339067577651 and parameters: {'krdp': 3.0575478347400114e-09, 'k1': 1.1734385857252395e-13, 'k2': 5.0260073704413486e-17, 'k3': 3.242224372954904e-15, 'k4_ref': 3.4148266792975705e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:14:40,370] Trial 132 finished with value: 2.1948250000000087 and parameters: {'krdp': 8.118389430055629e-10, 'k1': 1.0069081134452872e-12, 'k2': 1.1491033828736965e-16, 'k3': 1.8152199383198064e-16, 'k4_ref': 2.9745408753595655e-21}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:14:49,462] Trial 141 finished with value: 0.3006846664031295 and parameters: {'krdp': 2.7126391872226883e-09, 'k1': 1.2539344304178365e-13, 'k2': 5.764770272330721e-17, 'k3': 2.990247693478167e-15, 'k4_ref': 5.3603888153456386e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:14:51,797] Trial 142 finished with value: 0.10159363220638931 and parameters: {'krdp': 1.740656194363107e-09, 'k1': 1.0899038714309991e-13, 'k2': 1.4678846516115093e-17, 'k3': 4.872484147535747e-15, 'k4_ref': 1.465876596224482e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:14:54,804] Trial 143 finished with value: 0.15643833974129065 and parameters: {'krdp': 3.0295671765312257e-09, 'k1': 2.897368884200123e-13, 'k2': 8.631100894195897e-17, 'k3': 3.688765580296156e-15, 'k4_ref': 2.0538592798874016e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:15:06,686] Trial 144 finished with value: 0.1348558231844177 and parameters: {'krdp': 9.687162034807907e-10, 'k1': 1.048559156869372e-13, 'k2': 1.9696091809430947e-16, 'k3': 6.650820805196226e-15, 'k4_ref': 3.744085624761823e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:15:13,584] Trial 145 finished with value: 0.10201678596184885 and parameters: {'krdp': 6.321505249570192e-09, 'k1': 1.770885297952607e-13, 'k2': 2.877225302608262e-17, 'k3': 8.851790762183435e-15, 'k4_ref': 2.8659286519149128e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:15:21,353] Trial 146 finished with value: 0.18477886698146256 and parameters: {'krdp': 1.4959158930663575e-09, 'k1': 1.0151427278406029e-12, 'k2': 3.1086131754453277e-16, 'k3': 1.422298568919607e-14, 'k4_ref': 1.0184147031172159e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:15:29,915] Trial 147 finished with value: 0.16012059990507732 and parameters: {'krdp': 2.0871334439898883e-09, 'k1': 3.528141628966898e-14, 'k2': 1.73499682554568e-16, 'k3': 8.795956246440245e-17, 'k4_ref': 4.7705659159820564e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:15:35,126] Trial 148 finished with value: 0.1184101561883508 and parameters: {'krdp': 3.801044665334394e-09, 'k1': 2.3152690652706703e-14, 'k2': 9.002592117699674e-17, 'k3': 5.47109056539573e-15, 'k4_ref': 2.2004759749562402e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:15:42,173] Trial 149 finished with value: 0.09905992082151883 and parameters: {'krdp': 6.620655128133895e-10, 'k1': 2.2043857854041338e-13, 'k2': 3.9522327058384325e-17, 'k3': 8.15215755760879e-15, 'k4_ref': 3.86432946755077e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:15:44,198] Trial 150 finished with value: 0.44870953213481635 and parameters: {'krdp': 1.353533556016204e-09, 'k1': 8.346465659572528e-14, 'k2': 6.89935837977416e-17, 'k3': 1.2376116078494194e-14, 'k4_ref': 2.770397367548809e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:15:50,538] Trial 151 finished with value: 0.2412137007188842 and parameters: {'krdp': 9.383477208569123e-09, 'k1': 2.314911524905957e-15, 'k2': 1.4072967394257833e-16, 'k3': 2.980458390083403e-17, 'k4_ref': 1.3355847152491616e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:15:57,572] Trial 152 finished with value: 0.2609248026088364 and parameters: {'krdp': 3.481051862432798e-09, 'k1': 6.455204364929542e-13, 'k2': 4.7243977531939564e-17, 'k3': 2.0206257348064457e-14, 'k4_ref': 6.1674920516999964e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:16:08,101] Trial 153 finished with value: 0.739159842387725 and parameters: {'krdp': 5.105140259093394e-09, 'k1': 3.815380641004379e-15, 'k2': 6.129135573440601e-16, 'k3': 3.757229634198124e-15, 'k4_ref': 1.7735389703015047e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:16:18,346] Trial 154 finished with value: 0.23485013926338266 and parameters: {'krdp': 7.3194599619017785e-09, 'k1': 3.5904322661651793e-12, 'k2': 2.0163205624923797e-16, 'k3': 1.147673652357167e-14, 'k4_ref': 4.455634808761104e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:16:26,141] Trial 155 finished with value: 0.10232676853545175 and parameters: {'krdp': 2.433127312506156e-09, 'k1': 2.0365404635001878e-12, 'k2': 3.095595299242952e-16, 'k3': 1.745823287817502e-14, 'k4_ref': 7.722575733494995e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:16:32,287] Trial 156 finished with value: 0.10101918274036435 and parameters: {'krdp': 9.94894976042224e-10, 'k1': 1.289025328223926e-12, 'k2': 1.2298274358527364e-16, 'k3': 7.858016195865883e-15, 'k4_ref': 3.127732116726251e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:16:41,756] Trial 157 finished with value: 0.1014160147719142 and parameters: {'krdp': 5.2477215241077e-09, 'k1': 8.272537415750568e-13, 'k2': 1.6457593558400307e-16, 'k3': 4.855684070969982e-16, 'k4_ref': 5.6921363589568455e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:16:45,502] Trial 158 finished with value: 0.22783000931312736 and parameters: {'krdp': 5.806646440925032e-10, 'k1': 1.754168485676681e-12, 'k2': 9.750094082858208e-17, 'k3': 1.4317635265336088e-14, 'k4_ref': 2.341571269769415e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:16:51,328] Trial 159 finished with value: 0.07724667021874464 and parameters: {'krdp': 9.751632321773376e-09, 'k1': 2.461054604114946e-12, 'k2': 6.415804703887567e-17, 'k3': 3.1044635016804183e-16, 'k4_ref': 3.8436649309384265e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:17:03,341] Trial 160 finished with value: 0.5706181936486531 and parameters: {'krdp': 1.877125973626761e-09, 'k1': 4.398632516229309e-13, 'k2': 2.430310040556225e-16, 'k3': 7.624737615867206e-16, 'k4_ref': 8.640492034666298e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:23:09,119] Trial 105 finished with value: 0.15574183344886733 and parameters: {'krdp': 2.6236714177360034e-08, 'k1': 2.430493718911169e-12, 'k2': 7.903278824726511e-14, 'k3': 6.60312456416047e-16, 'k4_ref': 7.360245997952638e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 13:24:08,218] Trial 139 finished with value: 0.9081600622157832 and parameters: {'krdp': 2.8680615243154855e-09, 'k1': 9.947750243476343e-13, 'k2': 9.058552637820018e-14, 'k3': 3.143162224105264e-15, 'k4_ref': 2.159257100147532e-24}. Best is trial 118 with value: 0.009221147074878724.
# ...
# [I 2026-08-04 16:27:58,417] Trial 307 finished with value: 1.133758182470908 and parameters: {'krdp': 3.1656461234405867e-08, 'k1': 7.601048821184659e-15, 'k2': 8.519106583286783e-17, 'k3': 4.754785332089415e-16, 'k4_ref': 2.8088819306683826e-23}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 16:28:01,920] Trial 308 finished with value: 0.031993993026846475 and parameters: {'krdp': 1.1415739823540425e-09, 'k1': 1.0202173736430987e-14, 'k2': 5.0479033854832796e-17, 'k3': 6.639831471444477e-16, 'k4_ref': 2.9839140847199822e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 16:28:07,751] Trial 309 finished with value: 0.055722440491478516 and parameters: {'krdp': 1.0645901115247094e-09, 'k1': 1.3376152697441425e-14, 'k2': 3.448995460400561e-17, 'k3': 6.379220602293549e-16, 'k4_ref': 3.5219433691461796e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 16:28:13,792] Trial 310 finished with value: 0.2716131809444649 and parameters: {'krdp': 8.873166348338769e-10, 'k1': 1.0534987495446419e-14, 'k2': 5.390946928234911e-17, 'k3': 8.425118109851642e-16, 'k4_ref': 4.660066875638354e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 16:28:15,734] Trial 311 finished with value: 0.1618905708701684 and parameters: {'krdp': 2.417900136941185e-08, 'k1': 5.863921904380826e-15, 'k2': 4.264578652514203e-17, 'k3': 7.164662303766005e-16, 'k4_ref': 3.1598791283703047e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 16:50:52,828] Trial 284 finished with value: 0.27016381166702746 and parameters: {'krdp': 4.000340763477515e-09, 'k1': 1.858626788628488e-15, 'k2': 5.187840972711435e-13, 'k3': 1.0409931358436708e-15, 'k4_ref': 4.040241091376777e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 16:51:22,288] Trial 312 finished with value: 0.601534880318302 and parameters: {'krdp': 1.231730642731182e-09, 'k1': 2.1706718761173504e-14, 'k2': 1.5554376631595787e-14, 'k3': 5.2926324376334965e-16, 'k4_ref': 1.0444625060028182e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 16:51:37,466] Trial 314 finished with value: 0.24277814364931657 and parameters: {'krdp': 4.924111510395643e-10, 'k1': 7.599641692109741e-14, 'k2': 5.100549207431201e-17, 'k3': 3.7481395161773323e-16, 'k4_ref': 9.553066556018629e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 16:51:43,684] Trial 315 finished with value: 0.04913669856518885 and parameters: {'krdp': 2.7686470684737906e-08, 'k1': 3.574072916970053e-15, 'k2': 9.295492923831677e-17, 'k3': 6.11183444670306e-16, 'k4_ref': 2.5955706766298143e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 16:51:48,818] Trial 316 finished with value: 0.023188047195586287 and parameters: {'krdp': 1.697153236727574e-09, 'k1': 4.1184573971658794e-14, 'k2': 3.6198864094205007e-17, 'k3': 1.3216143176989547e-15, 'k4_ref': 3.1556469072335657e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 16:51:51,518] Trial 317 finished with value: 0.22114494792409098 and parameters: {'krdp': 1.3213194962273449e-11, 'k1': 9.78867380653344e-15, 'k2': 2.90877578814049e-17, 'k3': 8.927458859449437e-16, 'k4_ref': 1.5406005763196485e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:03:13,156] Trial 300 finished with value: 2.194825 and parameters: {'krdp': 1.743163694625522e-09, 'k1': 5.045531660227317e-14, 'k2': 6.7201740091069524e-15, 'k3': 7.234980294845794e-16, 'k4_ref': 3.3746516569585308e-19}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:03:18,826] Trial 319 finished with value: 0.09982821140942752 and parameters: {'krdp': 8.507801295973685e-08, 'k1': 4.0668907822418215e-14, 'k2': 3.9157577612566195e-17, 'k3': 1.4988335018724449e-15, 'k4_ref': 2.310627236288677e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:03:22,119] Trial 313 finished with value: 0.6276591645667973 and parameters: {'krdp': 3.686701474735623e-08, 'k1': 9.663202107141221e-15, 'k2': 9.254924071504282e-15, 'k3': 4.095487571621018e-16, 'k4_ref': 2.5213772483240833e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:03:25,811] Trial 320 finished with value: 0.09415478617139393 and parameters: {'krdp': 1.3333251134676033e-09, 'k1': 1.599291869155101e-14, 'k2': 2.397269174340825e-17, 'k3': 2.9530549812867854e-16, 'k4_ref': 3.2432720441642347e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:03:37,288] Trial 322 finished with value: 0.9736316024800346 and parameters: {'krdp': 8.137116432821584e-10, 'k1': 2.4712183019551363e-14, 'k2': 3.578865115644031e-17, 'k3': 1.0028338849915178e-15, 'k4_ref': 1.278632810251677e-23}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:03:38,063] Trial 321 finished with value: 1.6047204907930372 and parameters: {'krdp': 7.509548220306953e-10, 'k1': 1.7936893309410806e-14, 'k2': 2.4496866836713814e-17, 'k3': 1.3466252327738481e-17, 'k4_ref': 3.957235720247357e-23}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:03:42,188] Trial 323 finished with value: 0.07909251100591908 and parameters: {'krdp': 1.5875299129709555e-09, 'k1': 6.610147516700581e-15, 'k2': 5.3890888398444556e-17, 'k3': 4.464292195964249e-16, 'k4_ref': 1.7013293071649106e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:03:57,828] Trial 325 finished with value: 0.08541544364017545 and parameters: {'krdp': 1.1524414394341849e-09, 'k1': 7.571692500306617e-15, 'k2': 1.0301974609253602e-16, 'k3': 8.118500098087422e-16, 'k4_ref': 4.6667619899876685e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:04:10,328] Trial 318 finished with value: 0.04832475150421151 and parameters: {'krdp': 1.6939918515215417e-09, 'k1': 1.2767416404074027e-14, 'k2': 7.709099640905716e-15, 'k3': 1.379174647969555e-15, 'k4_ref': 1.388132653880987e-23}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:04:10,376] Trial 326 finished with value: 0.36134684289993196 and parameters: {'krdp': 1.8579051175568627e-09, 'k1': 6.325402309671477e-13, 'k2': 3.335129876897151e-17, 'k3': 1.52239933281342e-15, 'k4_ref': 6.849693435174601e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:04:11,787] Trial 328 finished with value: 1.029893937473262 and parameters: {'krdp': 4.309594151653141e-10, 'k1': 3.255095919573684e-14, 'k2': 6.501360312402603e-17, 'k3': 6.16753066331652e-16, 'k4_ref': 1.9151434087865595e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:14:28,309] Trial 202 finished with value: 1.0127747510323184 and parameters: {'krdp': 1.1167089580510716e-09, 'k1': 1.816065508294462e-13, 'k2': 3.127241618631898e-14, 'k3': 1.731406818741441e-15, 'k4_ref': 2.337972006039618e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:14:35,097] Trial 330 finished with value: 0.041031209568308205 and parameters: {'krdp': 5.418221945859902e-10, 'k1': 4.915030877541483e-15, 'k2': 4.2068839811072736e-17, 'k3': 4.849462514289475e-16, 'k4_ref': 3.0539015806588335e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:19:04,874] Trial 324 finished with value: 0.847487579503156 and parameters: {'krdp': 1.7900588033909998e-09, 'k1': 5.754159265760207e-15, 'k2': 2.6835751648265382e-14, 'k3': 1.3896255958275355e-15, 'k4_ref': 1.767122302132736e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:19:08,017] Trial 332 finished with value: 0.22937312581074554 and parameters: {'krdp': 4.855024173798705e-08, 'k1': 2.1067584567687924e-12, 'k2': 6.72174817720052e-17, 'k3': 1.041163069651978e-15, 'k4_ref': 1.3019578646918909e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:19:17,348] Trial 333 finished with value: 0.05068916985715983 and parameters: {'krdp': 1.653123242359301e-08, 'k1': 3.810909772883362e-14, 'k2': 9.973255727750442e-17, 'k3': 7.701934854983368e-16, 'k4_ref': 4.0797743114772414e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:22:05,532] Trial 329 finished with value: 0.8614984067196452 and parameters: {'krdp': 1.9603531537461686e-08, 'k1': 3.0109803194968825e-15, 'k2': 9.406323376340575e-14, 'k3': 1.065482028094755e-15, 'k4_ref': 2.914614682297274e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:22:11,535] Trial 335 finished with value: 0.05823285170168578 and parameters: {'krdp': 9.486694999629914e-10, 'k1': 7.899879844447061e-13, 'k2': 2.9951947528275005e-17, 'k3': 5.874675839467342e-16, 'k4_ref': 2.2194391983236323e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:23:10,572] Trial 336 finished with value: 2.194825 and parameters: {'krdp': 1.1064153325934188e-08, 'k1': 6.204479837814087e-14, 'k2': 1.9617422716135627e-17, 'k3': 1.2650414551859378e-14, 'k4_ref': 4.0695964081013226e-20}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:23:17,293] Trial 337 finished with value: 0.26391520642948846 and parameters: {'krdp': 1.2007607429692896e-09, 'k1': 1.0389693773787818e-12, 'k2': 4.755704390771417e-17, 'k3': 3.415689675762587e-16, 'k4_ref': 4.991565748164161e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:23:24,712] Trial 338 finished with value: 0.027078778886572452 and parameters: {'krdp': 3.198353867335953e-10, 'k1': 4.504278748938611e-16, 'k2': 6.05807357784847e-17, 'k3': 8.992314110288594e-16, 'k4_ref': 3.3386278358487814e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:23:33,329] Trial 339 finished with value: 0.4930460927390119 and parameters: {'krdp': 4.0799870591606097e-10, 'k1': 4.198490601193834e-15, 'k2': 6.562081773020738e-17, 'k3': 9.125227079676914e-16, 'k4_ref': 7.784744168186228e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:23:40,635] Trial 340 finished with value: 0.1769705960690002 and parameters: {'krdp': 3.7317167224933865e-10, 'k1': 3.2687188461685566e-16, 'k2': 8.282448966482565e-17, 'k3': 7.235383472800899e-16, 'k4_ref': 3.819714872419101e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:24:01,042] Trial 341 finished with value: 1.137184400848011 and parameters: {'krdp': 2.976296831219079e-10, 'k1': 1.271913207406512e-16, 'k2': 1.1037798046542491e-16, 'k3': 5.280145337509937e-16, 'k4_ref': 1.9524019423578522e-23}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:24:09,465] Trial 342 finished with value: 0.03575015886471917 and parameters: {'krdp': 2.269868425051097e-09, 'k1': 1.0178066768042585e-15, 'k2': 5.627997030804329e-17, 'k3': 1.1487025773891454e-15, 'k4_ref': 3.115702510350947e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:24:19,598] Trial 343 finished with value: 0.1046590238234921 and parameters: {'krdp': 1.2394239631477867e-10, 'k1': 1.0072140147033821e-14, 'k2': 1.473261439631473e-16, 'k3': 9.034495063771137e-16, 'k4_ref': 5.836036358392798e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:24:24,344] Trial 344 finished with value: 0.08364193126312552 and parameters: {'krdp': 2.681552730023726e-10, 'k1': 7.986675659970465e-17, 'k2': 4.258550696448746e-17, 'k3': 1.2329299831901053e-15, 'k4_ref': 1.4032149756863826e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:28:11,246] Trial 327 finished with value: 0.5436593020300058 and parameters: {'krdp': 4.975068859837268e-10, 'k1': 6.192953028855838e-13, 'k2': 9.37179672195997e-14, 'k3': 6.209854111754245e-16, 'k4_ref': 6.723585065460324e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:28:18,152] Trial 346 finished with value: 0.13588681331263436 and parameters: {'krdp': 8.652427654787776e-09, 'k1': 7.714257313826675e-16, 'k2': 7.582561595965256e-17, 'k3': 2.3152008462214046e-16, 'k4_ref': 4.1995022334092934e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:28:24,685] Trial 347 finished with value: 0.028724465415255064 and parameters: {'krdp': 1.9585265891514682e-10, 'k1': 2.814905505008534e-14, 'k2': 5.477514758835095e-17, 'k3': 7.608783368232218e-16, 'k4_ref': 2.12203688896653e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:28:28,841] Trial 348 finished with value: 0.41463911483149024 and parameters: {'krdp': 1.6655569882932438e-10, 'k1': 3.1561065678438084e-14, 'k2': 9.209817391803573e-17, 'k3': 1.4807590345183676e-16, 'k4_ref': 1.927207718864384e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:28:31,109] Trial 349 finished with value: 0.3512596679550606 and parameters: {'krdp': 2.207527192953872e-10, 'k1': 2.6289044205594314e-14, 'k2': 6.752118234765035e-17, 'k3': 9.03432234305701e-16, 'k4_ref': 1.046202589740625e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:28:42,052] Trial 350 finished with value: 0.021404112791710315 and parameters: {'krdp': 2.0880575475899375e-10, 'k1': 4.42492806998323e-16, 'k2': 5.822392207472876e-17, 'k3': 6.385084760036498e-16, 'k4_ref': 3.0418558839812453e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:28:45,692] Trial 351 finished with value: 0.2655449697238531 and parameters: {'krdp': 3.3692483761461875e-10, 'k1': 2.686785584237769e-16, 'k2': 1.116699009061165e-16, 'k3': 4.841919387217318e-16, 'k4_ref': 1.5624842048712284e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:29:01,089] Trial 352 finished with value: 0.5808848314864458 and parameters: {'krdp': 1.8352158378191982e-10, 'k1': 4.582383944068277e-14, 'k2': 5.819904134085246e-17, 'k3': 7.418018665465625e-16, 'k4_ref': 9.523856430507672e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:29:05,374] Trial 353 finished with value: 0.12473816342443096 and parameters: {'krdp': 1.9470572288093646e-10, 'k1': 4.855013940430371e-16, 'k2': 1.6351362917638253e-16, 'k3': 3.9198402619558573e-16, 'k4_ref': 2.1708783241304077e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:29:13,057] Trial 354 finished with value: 0.2653368499440728 and parameters: {'krdp': 1.3178543629829526e-10, 'k1': 1.2515246285887931e-15, 'k2': 3.653448110565027e-17, 'k3': 7.540462992949515e-16, 'k4_ref': 3.602695909269523e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:29:22,298] Trial 355 finished with value: 0.5461088899464 and parameters: {'krdp': 8.651510465911106e-11, 'k1': 6.642234069421525e-14, 'k2': 7.682548319206296e-17, 'k3': 1.1976042334878327e-15, 'k4_ref': 4.881279266852793e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:30:48,236] Trial 356 finished with value: 0.366493674358652 and parameters: {'krdp': 1.4661462658043377e-10, 'k1': 1.9987590309893758e-14, 'k2': 2.068065244774187e-15, 'k3': 9.721414079156695e-16, 'k4_ref': 2.8709753363936746e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:30:57,540] Trial 357 finished with value: 0.030437066330205525 and parameters: {'krdp': 3.3161589715071824e-10, 'k1': 4.792034767876772e-16, 'k2': 9.66027335872996e-17, 'k3': 6.12257583305427e-16, 'k4_ref': 1.9594483970178004e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:37:07,070] Trial 334 finished with value: 0.5905598955077382 and parameters: {'krdp': 8.795687313365437e-10, 'k1': 8.36425549270646e-13, 'k2': 6.992747672763425e-14, 'k3': 1.5368454507540705e-16, 'k4_ref': 2.968280475025242e-24}. Best is trial 118 with value: 0.009221147074878724.
# [I 2026-08-04 17:54:29,039] Trial 345 finished with value: 0.5297770102870667 and parameters: {'krdp': 2.1518822925187555e-10, 'k1': 8.148213649481674e-15, 'k2': 2.4317845266466785e-12, 'k3': 1.6638544294975836e-16, 'k4_ref': 4.091120363484435e-24}. Best is trial 118 with value: 0.009221147074878724.

# %% [markdown]
# Visualizing the calibration result

# %%
model = ccl()
for key, value in study.best_params.items():
    model.parameters[key] = value
sol_hist = []
x = [0] + [0]*len(r_m) + model.prd0.tolist()
for i_cycle in range(7):
        sol = solve_ivp(fun=model.dxdt, y0=x, t_span=(0, 5000*6), method="BDF")
        sol_hist.append(sol)
        x = sol.y[:, -1]
sim_data = [1]+[(trapezoid(y=(r_m ** 2) * sol_hist[i_sol+1].y[-len(r_m):,-1], x=r_m))/(trapezoid(y=(r_m ** 2) * model.prd0, x=r_m)) for i_sol in range(len(sol_hist)-1)]
plt.figure(figsize=(6.4,3))
plt.plot([x*5000 for x in range(7)], exp_data, linestyle='--', marker='o', label = "exp. data", color = "grey")
plt.plot([x*5000 for x in range(7)], sim_data, label = "Simulation data", marker = "^")
plt.legend()
plt.xlabel("Cycles",fontsize=13)
plt.ylabel("ECSA",fontsize=13)
plt.grid()

print(f"MSE = {np.sum((np.array(exp_data) - np.array(sim_data)) ** 2):.4f}")
# Out:
# MSE = 0.0220

# %%
model.parameters
# Out:
# {'krdp': 1.7695747310540784e-11,
#  'k1': 1.7350974368394175e-17,
#  'k1_ref': 1e-18,
#  'k2': 6.334637862479844e-15,
#  'k2_ref': 1e-13,
#  'k3': 1.1299039177701413e-14,
#  'k4': 0,
#  'k5': 0,
#  'k4_ref': 1.3160740883282697e-23}
